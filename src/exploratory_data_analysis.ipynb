# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train = pd.read_csv('~/github/UTSKaggle/data/input/train.csv')
train_cleaned = pd.read_csv('~/github/UTSKaggle/data/transformed_input/train.csv')

# %%
train.describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Age</th>
#       <th>Fnlwgt</th>
#       <th>Education years</th>
#       <th>Capital gain</th>
#       <th>Capital loss</th>
#       <th>Work hours per week</th>
#       <th>Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>38000.000000</td>
#       <td>38000.000000</td>
#       <td>3.800000e+04</td>
#       <td>38000.000000</td>
#       <td>38000.000000</td>
#       <td>38000.000000</td>
#       <td>38000.000000</td>
#       <td>38000.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>23987.651500</td>
#       <td>38.525711</td>
#       <td>1.893863e+05</td>
#       <td>10.069842</td>
#       <td>1098.063289</td>
#       <td>87.803211</td>
#       <td>40.483026</td>
#       <td>0.239132</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>13840.226031</td>
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38000 entries, 0 to 37999
# Data columns (total 16 columns):
# ID                     38000 non-null int64
# Age                    38000 non-null int64
# Employment class       38000 non-null object
# Fnlwgt                 38000 non-null int64
# Education level        38000 non-null object
# Education years        38000 non-null int64
# Marital status         38000 non-null object
# Occupation             38000 non-null object
# Relationship status    38000 non-null object
# Race                   38000 non-null object
# Sex                    38000 non-null object
# Capital gain           38000 non-null int64
# Capital loss           38000 non-null int64
# Work hours per week    38000 non-null int64
# Native country         38000 non-null object
# Salary                 38000 non-null int64
# dtypes: int64(8), object(8)
# memory usage: 4.6+ MB

# %%
train.hist(figsize=(16, 20), bins=20, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x10e976ad0>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x10f19ef50>]], dtype=object)

# %%
pd.crosstab(train['Employment class'],train['Salary'], margins=True)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Salary</th>
#       <th>0</th>
#       <th>1</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Employment class</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>?</th>
#       <td>1956</td>
#       <td>240</td>
#       <td>2196</td>
#     </tr>
#     <tr>
#       <th>Federal-gov</th>
#       <td>689</td>
#       <td>458</td>
#       <td>1147</td>
#     </tr>
#     <tr>
#       <th>Local-gov</th>
#       <td>1823</td>
#       <td>675</td>
#       <td>2498</td>
#     </tr>
#     <tr>
#       <th>Never-worked</th>
#       <td>8</td>
#       <td>0</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Private</th>
#       <td>20582</td>
#       <td>5810</td>
#       <td>26392</td>
#     </tr>
#     <tr>
#       <th>Self-emp-inc</th>
#       <td>577</td>
#       <td>708</td>
#       <td>1285</td>
# ...

# %%
pd.crosstab(train['Education level'],train['Salary'], margins=True)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Salary</th>
#       <th>0</th>
#       <th>1</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Education level</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10th</th>
#       <td>1040</td>
#       <td>85</td>
#       <td>1125</td>
#     </tr>
#     <tr>
#       <th>11th</th>
#       <td>1238</td>
#       <td>78</td>
#       <td>1316</td>
#     </tr>
#     <tr>
#       <th>12th</th>
#       <td>458</td>
#       <td>43</td>
#       <td>501</td>
#     </tr>
#     <tr>
#       <th>1st-4th</th>
#       <td>187</td>
#       <td>11</td>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>5th-6th</th>
#       <td>361</td>
#       <td>20</td>
#       <td>381</td>
#     </tr>
#     <tr>
#       <th>7th-8th</th>
#       <td>687</td>
#       <td>53</td>
#       <td>740</td>
#     </tr>
#     <tr>
# ...

# %%
pd.crosstab(train['Marital status'],train['Salary'], margins=True)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Salary</th>
#       <th>0</th>
#       <th>1</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Marital status</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Divorced</th>
#       <td>4754</td>
#       <td>533</td>
#       <td>5287</td>
#     </tr>
#     <tr>
#       <th>Married-AF-spouse</th>
#       <td>18</td>
#       <td>16</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>Married-civ-spouse</th>
#       <td>9620</td>
#       <td>7730</td>
#       <td>17350</td>
#     </tr>
#     <tr>
#       <th>Married-spouse-absent</th>
#       <td>437</td>
#       <td>48</td>
#       <td>485</td>
#     </tr>
#     <tr>
#       <th>Never-married</th>
#       <td>11920</td>
#       <td>594</td>
#       <td>12514</td>
#     </tr>
#     <tr>
#       <th>Separated</th>
#       <td>1135</td>
# ...

# %%
pd.crosstab(train['Occupation'],train['Salary'], margins=True)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Salary</th>
#       <th>0</th>
#       <th>1</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>Occupation</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>?</th>
#       <td>1964</td>
#       <td>240</td>
#       <td>2204</td>
#     </tr>
#     <tr>
#       <th>Adm-clerical</th>
#       <td>3722</td>
#       <td>615</td>
#       <td>4337</td>
#     </tr>
#     <tr>
#       <th>Armed-Forces</th>
#       <td>12</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Craft-repair</th>
#       <td>3810</td>
#       <td>1087</td>
#       <td>4897</td>
#     </tr>
#     <tr>
#       <th>Exec-managerial</th>
#       <td>2461</td>
#       <td>2229</td>
#       <td>4690</td>
#     </tr>
#     <tr>
#       <th>Farming-fishing</th>
#       <td>1044</td>
#       <td>130</td>
# ...

# %%
df_num_corr = train.corr()['Salary'][:-1] # -1 because the latest row is SalePrice

golden_features_list = df_num_corr[abs(df_num_corr) > 0].sort_values(ascending=False)

print("There is {} strongly correlated values with Salary:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There is 7 strongly correlated values with Salary:
# Education years        0.330425
# Age                    0.232510
# Work hours per week    0.227400
# Capital gain           0.226899
# Capital loss           0.149718
# ID                     0.000839
# Fnlwgt                -0.008803
# Name: Salary, dtype: float64
